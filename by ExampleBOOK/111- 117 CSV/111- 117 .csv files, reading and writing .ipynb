# %%
#example code

#import csv (comma seperated values) libary 

import csv

#create and write ("w") in document (if exist will be overwriten)
file = open ("Stars.csv", "w")

newRecord = "Brian,73,Taurus\n"
file.write(str(newRecord))
file.close()

#append data points ("a") - means to add something 

file = open ("Stars.csv", "a")
name = input("Enter name: ")
age = input ("Enter age: ")
star = input ("Enter star sign: ")
newRecord = name + ", "+ age + ", " + star +"\n"
file.write(str(newRecord))
file.close()


#read file ("r")

file = open ("Stars.csv", "r")
for row in file: 
    print (row)
    
# read specific rows (reads the second line == index 1 )

file = open ("Stars.csv", "r")
reader = csv.reader(file)
rows = list(reader)
print(rows[1])

#look for specific line
file = open ("Stars.csv", "r")
search = input("what are you looking for? ")
reader = csv.reader(file)
for row in file: 
    if search in str(row): 
        print(row)

# %%
#repeat challange no 111 

import csv

file = open ("Relationships.csv", "w")

newRecord = "Kilian DuHoux, 2016, 5 months \n"
file.write(str (newRecord))

newRecord = "Tobe Ofili, 2019, 8 months \n"
file.write(str (newRecord))

newRecord = "Valentin Engel, 2012, 0 months \n"
file.write(str (newRecord))

newRecord = "Darius ???, 2019, 0 months \n"
file.write(str (newRecord))


file.close()




file = open ("Relationships.csv", "a")

name = input ("Boyfriends name: ")

start = int(input("start of relationship: "))

duration = int(input("duration of realtionship in months: "))

newRecord = str(name) + ", " + str (start) + ", " + str(duration) + " months"+"\n"

file.write(str(newRecord))
file.close()

print ("\nAll the boyfriends: \n")

file = open ("Relationships.csv", "r")
for row in file: 
    print(row)
# Out:
# Boyfriends name: Julian
# start of relationship: 2001
# duration of realtionship in months: 1
#
# All the boyfriends:
#
# Kilian DuHoux, 2016, 5 months
#
# Tobe Ofili, 2019, 8 months
#
# Valentin Engel, 2012, 0 months
#
# Darius ???, 2019, 0 months
#
# Julian, 2001, 1 months

# %%
#challange 111 (create new csv file, Books.csv)

#import csv libary (remember: comma seperated values)
import csv

#write new file 
file = open ("Books.csv", "w")

newRecord = "To Kill, Harper Lee, 1960 \n"
file.write(str(newRecord))
newRecord = "A brief, Stehpen Hawking,  1988\n"
file.write(str(newRecord))
newRecord = "The great Gatsby, F. Scott Fritzgeradl, 1992\n"
file.write(str(newRecord))
newRecord = "The Man who mistook his wife for a hat, oliver ssacks, 1985\n"
file.write(str(newRecord))
newRecord = "Pride and Prejudice, Jane Austen, 1813\n"
file.write(str(newRecord))

#important: that saves the document! 
file.close()

# %%
#challange 112

file = open ("Books.csv", "a")
book = input("book title: ")
author = input("book author: ")
published = input ("published: ")
newRecord = book + ", " + author + ", " + published + "\n"

#transform the ints into str! 
file.write(str(newRecord))

#close to safe the changes made
file.close ()

file = open("books.csv", "r")
for row in file: 
    print (row)

# %%
#challange 113 (adding to the list)
import csv 

#how many addings needed 
how_many = int(input("how many books do you want to add? "))


file = open ("Books.csv", "a")
for i in range (0, how_many): 
    book = input("book title: ")
    author = input("book author: ")
    published = input ("published: ")
    newRecord = book + ", " + author + ", " + published + "\n"
    file.write(str(newRecord))
file.close ()

# search for specific line content and print the whole line 
print ("---"*5)
file = open("Books.csv", "r")
search_author = input("which author are you interested in? ")
reader = csv.reader(file)

#goes though the whole document 
for row in file: 
    #looks for specific value 
    if search_author in str(row): 
        print (row)

# %%
#repeat 114 (hard one! using the relationship.csv)


import csv 

#show the whole list! 

print ("\nAll the relationships:\n")
file = open ("Relationships.csv", "r")

for row in file:
    print (row)
    

start = int(input("Enter a start year:"))
end = int(input("Enter an end year:"))

file = list(csv.reader(open("Relationships.csv")))
temp= []
for row in file: 
    temp.append(row)

x = 0 
for row in temp: 
    if start <= int (temp [x][1]) and end >= int(temp [x][1]): 
        print (temp [x])
        
    x = x+1
# Out:
# All the relationships:
#
# Kilian DuHoux, 2016, 5 months
#
# Tobe Ofili, 2019, 8 months
#
# Valentin Engel, 2012, 0 months
#
# Darius ???, 2019, 0 months
#
# Julian, 2001, 1 months
#
# Enter a start year:2000
# Enter an end year:2020
# ['Kilian DuHoux', ' 2016', ' 5 months ']
# ['Tobe Ofili', ' 2019', ' 8 months ']
# ['Valentin Engel', ' 2012', ' 0 months ']
# ['Darius ???', ' 2019', ' 0 months ']
# ['Julian', ' 2001', ' 1 months']

# %%
#challange 114 

#import the libary for csv
import csv 

#range, by user input

start = int(input("start year: "))
end = int(input("end year: "))

#the data is stored in str therefore must be stored in temporary list

file = list(csv.reader(open("Books.csv")))
tempo = []
for row in file: 
    tempo.append(row)
    
x = 0 
for row in file: 
    if start >= int(tempo[x][2]) and end <= int (tempo[x][2]): 
        print (tempo [x])
    x = x+1

# %%
#challange 115

import csv 

file = open ("Books.csv", "r")

row_index = 1
for row in file: 
    print (row_index,": ", row)
    row_index= row_index+1

# %%
#challange 116 (very hard)

import csv 

#import csv data into list 

file = list(csv.reader(open("Books.csv")))

#create an empty list (only for temporary useage)
bookies = []

#extend the list as long as the lines in the csv file 
for row in file: 
    bookies.append(row)
            
print ("---"*20)        
print("original list: ")
print ("---"*20)
for i in bookies: 
    print(i)
            
            
#delete, ask which line 

print ("---"*20)
            
delete = int(input("which row do you want to delete from the list? ")) 

del bookies[delete]

print ("---"*20)        
print("list w/o picked line: ")
print ("---"*20)

x = 0 
for i in bookies: 
    print(i)
    x = x + 1
    
    
print ("---"*20)
            
alter = int(input("which line do you want to change? ")) 
where = int(input("which index: "))
new = input("what shall be the new value? ")

bookies[alter][where]= new 

print ("---"*20)        
print("list w/o picked line and with changed value: ")
print ("---"*20)

x = 0 
for i in bookies: 
    print(i)
    x = x + 1
    
print ("---"*20)    
print ("the list is now being stored in the orginal data")
print ("---"*20)  

file = open("Books.csv", "w")
x=0
for row in bookies: 
    newrecord = bookies [x][0] + ", " + bookies [x] [1]+ ", " +  bookies [x][2] + "\n" 
    file.write(newrecord)
    x= x+1
file.close()

# %%
#rep challange no 116 (with relationship data)

import csv 

#import data from csv into list 

file = list(csv.reader(open("Relationships.csv")))

tempi_list = []
print ("\nOriginal list:\n ")

for row in file: 
    tempi_list.append(row)
    print(row )
    
#let the user delete a row form the list 

select_row = int(input("Which row do you want to delete? "))

del tempi_list [select_row]

print ("\nList w/o deleted boyfriend:\n ")

for row in tempi_list: 
    print (row)
    
#let user change data 

change_line = int(input ("Which line do you want to change? "))
change_position = int(input( "Which position do you want to change? "))

to = input ("What should be written at the postion instead? ")

tempi_list [change_line] [change_position] = to 


print ("\nChanged List:\n ")

for row in tempi_list: 
    print (row)
    
    
    
#overwrite the existing csv data! 

file = open ("Relationships.csv", "w")
x = 0 
for row in tempi_list: 
    newRecord = tempi_list [x] [0] + ", " + tempi_list [x] [1] + ", " + tempi_list [x] [2]+ "\n"
    file.write (newRecord)
    x = x+1
file.close()
# Out:
# Original list:
#
# ['Tobe Ofili', '  2019', '  8 months ']
# ['Valentin Engel', '  2012', '  0 months ']
# ['Darius thought me Python ', '  2019', '  0 months ']
# ['Julian', '  2001', '  1 months']

# %%
#challange no 117 (math quiz)



import csv



file = open ("Math.csv", "a")

name = input("What is your name? ")
q_1 = int(input("what is your favorit number? "))
q_2 = int(input ("do you have another one? "))
result = q_1 + q_2

#transfering all variables in str
q_1 = str(q_1)
q_2 = str(q_2)
result = str(result)

new_record = name + ", " + "has picket" + q_1 + ", " + "and" + q_2+ "as their numbers, this results in:" + result + "\n"
file.close()
