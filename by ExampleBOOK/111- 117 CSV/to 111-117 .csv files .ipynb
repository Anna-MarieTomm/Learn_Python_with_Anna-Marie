# %%
# addapted 111 & 112

#crete new document 

import csv 

file = open ("Series.csv", "w")

newRecord = "Call the Midwfe, BBC, 2000 \n"
file.write(str (newRecord))

file.close()

#add new entries 

file = open("series.csv", "a")

newRecord = "Simpson, ProSieben, 1999\n"
file.write(str (newRecord))
newRecord = "Mieten Kaufen Wohnen, RTL, 2010\n"
file.write(str (newRecord))
newRecord = "Tagesschau, das Erste, 2020\n"
file.write(str (newRecord))

file.close()

#display the file: 

file = open ("Series.csv", "r")
for serie in file: 
    print(serie + "\n")

# %%
# addapted 113

import csv 

how_many = int(input("how many record do you want to add? "))


for i in range(0, how_many): 
    file = open ("Series.csv", "a")
    series_name = input("series name: ")
    channel = input("channel: ")
    year = input ("year: ")
    newRecord = series_name + ", " + channel + ", " + year + "\n" 
    file.write(str(newRecord))
    file.close()
print ("the new whole list of series: \n")

file = open ("Series.csv", "r")
for i in file: 
    print(i)

print ("---"* 10)

pick_channel = input("which is your favorit channel: ")

print ("\nfrom your favorit series there are thus entries: \n")
file = open ("Series.csv", "r")
reader =  csv.reader(file)
for row in file: 
    if pick_channel in str(row): 
        print (row)

# %%
# adapted 114

import csv

start = int(input("start year: "))
end = int(input("end year: "))

#creation of temporary list 
file = list (csv.reader (open("Series.csv")))
tempo = []
# fill in the list, first print in all the lines 
for row in file: 
    tempo.append(row)

    
x = 0
for row in tempo: 
    if int(tempo[x][2]) >= start and int(tempo [x] [2]) <= end : 
        print(tempo[x])
    x = x + 1

# %%
# adapted 115

import csv 

file = open ("Series.csv", "r")
line = 1

for row in file: 
    print (line,":", row)
    line = line +1

# %%
#adapted 116

import csv 

#import the data of the series.csv into a list 

file = list(csv.reader(open ("Series.csv")))

temopList  = []

print ("\nold list: \n")
for row in file: 
    temopList.append(row)
    print(row)
    
delete = int(input("\n \nwhich list do you want to delete? "))

print("\nlist w/o old entry: \n")

temopList.remove(temopList[delete])
                 
for row in temopList: 
    print(row)

    
    
# change in data 

change_line = int(input("\nwhich line do you want to change? "))
change_postion = int(input("\nwhich position do you want to change? "))
to = input("\nwhat should be there instead? \n")
temopList [change_line] [change_postion]= to 

print("\nlist w/o old entry and with change: \n")
for row in temopList: 
    print (row)
    

#safe everything in the orginal data: 

file = open ("Series.csv", "w")
x = 0 
for row in temopList: 
    newrecord = temopList [x] [0] + ", " + temopList [x] [1] + ", " +temopList[x] [2] + "\n "
    file.write(newrecord)
    x = x+1
file.close()
# Out:
# old list:
