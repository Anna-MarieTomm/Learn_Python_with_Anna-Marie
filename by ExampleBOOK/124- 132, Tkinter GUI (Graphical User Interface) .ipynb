# %%
#example code 

from tkinter import *

def Call (): 
    #adds text to screen when the button is pressed
    msg = Label (window, text = "I love you, Tobe")
    msg.place(x=60, y = 100)
    button ["bg"] = "blue"
    button ["fg"] = "green"
    
    
window = Tk()
window.title ("Currious? than press!")
window.geometry("400x220")

button = Button (text = "Anna´s message", command = Call)
button.place (x= 60, y= 40, width = 240, height = 50)
window.mainloop()

# %%
#challange 124

#import the library 
from tkinter import *

def greeting():
    name = entry.get()
    sentence = str("Hello " + name)
    
    message ["text"] = sentence
    
    
#set up the window
window = Tk ()
window.title ("Your name")
window.geometry("400x250")

#label, does do anything 
label = Label (text = "Enter your name")
label.place(x=20,y= 20, width = 100, height = 50)


#entry 
entry = Entry (text = 0)
entry.place(x= 140, y = 20, width = 100, height = 50)
entry.focus()

#button 
button = Button (text = "Press", command = greeting)
button.place(x= 260, y = 20, width = 100, height = 50)

#message 
message = Message (text = 0)
message.place (x=140,y= 70, width = 200, height = 50)
message ["bg"] = "yellow"
message ["fg"] = "blue"


window.mainloop()

# %%
#challange 125

import random 
from tkinter import *

#function 
def role (): 
    dice_number = random.randint(1,6)
    message = str(dice_number)
    output_box["text"]= message 
    
#window 
window = Tk()
window.title ("lets roll the dice")
window.geometry("400x200")
window ["bg"] = "yellow"

#3. Press the button box (must change the color)
button_box = Button (text = "Click here to roll the dice", command = role)
button_box.place(x = 50, y = 20, width = 200, height = 50)
button_box ["bg"] = "orange"
button_box ["fg"] = "green"


#4. Output box  
output_box = Message (text = "")
output_box.place(x = 100, y= 90, width = 100, height = 50)
output_box ["bg"] = "purple"
output_box ["fg"] = "orange"


window.mainloop()

# %%
#challange 126

#either one adds to the number before or once clears everything and starts from scratch

from tkinter import *


#adding function 

def adding(): 
    number = entry_number.get()
    number = int(number)
    answer = message_result["text"]
    answer = int(answer)
    total = number +answer
    message_result ["text"] = total

#clear function 

def clearing(): 
    total = 0
    message_result["text"] = 0
    entry_number.delete (0, END)
    entry_number.focus()


# setting the values for the calculations
total = 0 
number = 0 


#create window 
window = Tk()
window.geometry("500x100")

#First part  (the program for adding)
#Label (press here)
label_1 = Label(text = "Enter Number")
label_1.place(x = 50, y = 20, width = 100, height = 20)
label_1 ["bg"] = "yellow"

#Entry (number)
entry_number = Entry (text = 0)
entry_number.place(x = 170, y = 20, width = 150, height = 20)
entry_number.focus()

#Button ("Add")

add_button = Button (text = "ADD", command = adding)
add_button.place(x = 350, y = 20, width = 100, height = 20)



# second part 
# Label (Answer = )
label_2 = Label(text = "Answer")
label_2.place(x = 50, y = 60, width = 100, height = 20)
label_2 ["bg"] = "yellow"


# Message (should give the caluclation result)
message_result = Message (text = 0)
message_result.place(x = 170, y = 60, width = 150, height = 20)
message_result ["relief"] = "sunken"

# Button  ("Clear")
clear_button = Button (text = "CLEAR", command = clearing)
clear_button.place(x = 350, y = 60, width = 100, height = 20)




window.mainloop()

# %%
#challange 127 

from tkinter import * 

#create window 
window = Tk()
window.geometry("500x200")
window ["bg"] = "yellow"
window.title("Task No. 127")



# create a list 
list_names = [] 


#adding function 

def adding(): 
    name = entry_name.get()
    name_list.isert(END, name)
    answer = message_result["text"]
    answer = str(answer)
    list_names = list_names.append(name)
    message_result ["text"] = str(list_names)

#clear function 

def clearing(): 
    list_names = [] 
    message_result["text"] = "empty"
    entry_number.delete (0, END)
    entry_number.focus()





#create window 
window = Tk()
window.geometry("500x100")

#First part  (the program for adding)
#Label (press here)
label_1 = Label(text = "Enter a name")
label_1.place(x = 50, y = 20, width = 100, height = 20)
label_1 ["bg"] = "white"

#Entry (number)
entry_name = Entry (text = 0)
entry_name.place(x = 170, y = 20, width = 150, height = 20)
entry_name.focus()

#Button ("Add")

add_button = Button (text = "ADD", command = adding)
add_button.place(x = 350, y = 20, width = 100, height = 20)


# second part 
# Label (Answer = )
label_2 = Label(text = "List")
label_2.place(x = 50, y = 60, width = 100, height = 20)
label_2 ["bg"] = "white"

# Message (should give the caluclation result)
message_result = Message (text = "empty")
message_result.place(x = 170, y = 60, width = 150, height = 20)
message_result ["relief"] = "sunken"

# Button  ("Clear")
clear_button = Button (text = "CLEAR", command = clearing)
clear_button.place(x = 350, y = 60, width = 100, height = 20)


window.mainloop()

# %%
#challange 127

from tkinter import * 

#window setup 

window = Tk()
window.geometry ("500x400")
window["bg"] = "yellow"
window.title ("challange 127")

#functions add 
def add(): 
    name = entry.get()
    name_List.insert(END, name)
    entry.delete(0, END)
    entry.focus()


#function clear 
def clear (): 
    name_List.delete(0,END)
    entry.focus()

#label 
label = Label (text = "Enter name")
label.place(x = 20, y = 50, width = 100, height = 30)
label ["bg"] = "green"
label ["fg"] = "white"

#entry 
entry = Entry (text = 0)
entry.place(x = 140, y = 50, width = 100, height = 30)
entry ["bg"] = "white"
entry ["fg"] = "blue"
entry.focus()

#button add 
add_button = Button (text = "ADD", command = add)
add_button.place(x = 260, y = 50, width = 100, height = 30)
add_button ["bg"] = "purple"
add_button ["fg"] = "blue"


#button clear 

clear_button = Button (text = "Clear", command = clear)
clear_button.place(x = 260, y = 130, width = 100, height = 30)
clear_button ["bg"] = "purple"
clear_button ["fg"] = "blue"



#list (message)
name_List = Listbox()
name_List.place(x = 140, y = 130, width = 100, height = 130)
name_List ["bg"] = "orange"
name_List ["fg"] = "black"




window.mainloop()

# %%
#challange 128 (converter)

from tkinter import * 

#set up the window 
window = Tk()
window.geometry ("500x400")
window["bg"] = "yellow"
window.title ("distance converter")


#function
def convert_to_miles ():
    non_converted = entry.get()
    non_converted = int(non_converted)
    result = non_converted * 0.6214
    result = round (result, 2)
    converted ["text"] = (str(result) + "\nMiles") 

def convert_to_km (): 
    non_converted = entry.get()
    non_converted = int(non_converted)
    result = non_converted * 1.6093
    result = round (result, 2)
    converted ["text"] = (str(result) + "\nkm") 

#label (insert unit)
label = Label (text = "Enter unit")
label.place(x = 20, y = 50, width = 100, height = 30)
label ["bg"] = "green"
label ["fg"] = "white"

#entry unit 
entry = Entry (text = 0)
entry.place(x = 140, y = 50, width = 100, height = 30)
entry ["bg"] = "white"
entry ["fg"] = "blue"
entry.focus()



#button (from km to miles)
to_miles_button = Button (text = "to Miles", command = convert_to_miles)
to_miles_button.place(x = 260, y = 50, width = 100, height = 30)
to_miles_button ["bg"] = "purple"
to_miles_button ["fg"] = "blue"


#button (from miles to km)
to_km_button = Button (text = "to Kilometers", command = convert_to_km)
to_km_button.place(x = 260, y = 130, width = 100, height = 30)
to_km_button ["bg"] = "purple"
to_km_button ["fg"] = "blue"


#message (other unit)
converted = Message (text  = 0)
converted.place(x = 140, y = 130, width = 100, height = 60)
converted ["bg"] = "orange"
converted ["fg"] = "black"





window.mainloop()

# %%
#challange 129 

from tkinter import * 


#set up window 
window = Tk()
window.geometry ("500x400")
window["bg"] = "yellow"
window.title ("isdigit()")


#function (check if it is digit, than add if not clear entry box)
def diggit_add ():
    number = entry.get()
    number.isdigit() 
    if number.isdigit () == True: 
        number_List.insert (END, number)
        entry.delete (0,END)
        entry.focus()
    else:
        entry.delete(0,END)
        entry.focus()


def clear (): 
    number_List.delete(0,END)
    entry.focus()

#label (add number)
label = Label (text = "Enter a number:")
label.place (x = 20, y = 20, width = 100, height = 30)
label ["bg"] = "green"
label ["fg"] = "white"

#entry (number)
entry = Entry (text = 0)
entry.place(x = 140, y = 20, width = 100, height = 30)
entry ["bg"] = "white"
entry ["fg"] = "blue"
entry.focus()


#button (is digit, and add)
add_button = Button (text = "ADD, if digit", command = diggit_add)
add_button.place(x = 260, y = 20, width = 100, height = 30)
add_button ["bg"] = "purple"
add_button ["fg"] = "blue"

#button (clear)
clear_button = Button (text = "CLEAR", command = clear)
clear_button.place(x = 260, y = 70, width = 100, height = 30)
clear_button ["bg"] = "purple"
clear_button ["fg"] = "blue"


#list (with all digits)

number_List = Listbox ()
number_List.place (x = 140, y = 70,  width = 100, height = 80)

window.mainloop()

# %%
#challange 130 

from tkinter import * 
import csv 

#set up window 
window = Tk()
window.geometry ("500x400")
window["bg"] = "yellow"
window.title ("safe list to csv file")


#function (check if it is digit, than add if not clear entry box)
def diggit_add ():
    number = entry.get()
    number.isdigit() 
    if number.isdigit () == True: 
        number_List.insert (END, number)
        entry.delete (0,END)
        entry.focus()
    else:
        entry.delete(0,END)
        entry.focus()


def clear (): 
    number_List.delete(0,END)
    entry.focus()
    
def safe (): 
    file = open ("Numbers.csv", "w")
    temp_list = number_List.get(0,END)
    item = 0
    for row in temp_list: 
        newrecord = temp_list[item] + "\n"
        file.write (str (newrecord))
        item = item +1
        
        
    file.close()
    

#label (add number)
label = Label (text = "Enter a number:")
label.place (x = 20, y = 20, width = 100, height = 30)
label ["bg"] = "green"
label ["fg"] = "white"

#entry (number)
entry = Entry (text = 0)
entry.place(x = 140, y = 20, width = 100, height = 30)
entry ["bg"] = "white"
entry ["fg"] = "blue"
entry.focus()


#button (is digit, and add)
add_button = Button (text = "ADD, if digit", command = diggit_add)
add_button.place(x = 260, y = 20, width = 100, height = 30)
add_button ["bg"] = "purple"
add_button ["fg"] = "blue"

#button (clear)
clear_button = Button (text = "CLEAR", command = clear)
clear_button.place(x = 260, y = 70, width = 100, height = 30)
clear_button ["bg"] = "purple"
clear_button ["fg"] = "blue"

#button safe to .csv file
safe_button = Button (text = "SAFE, to csv", command = safe)
safe_button.place(x = 260, y = 120, width = 100, height = 30)
safe_button ["bg"] = "purple"
safe_button ["fg"] = "blue"



#list (with all digits)

number_List = Listbox ()
number_List.place (x = 140, y = 70,  width = 100, height = 80)

window.mainloop()

# %%
#challange 131 

#new csv file with name and age of person which will be added then 

from tkinter import *
import csv 

#functions

#create csv
def create (): 
    file = open ("Name_Age.csv", "w")
    file.close()
    

#add to csv 
def add(): 
    data = entry_name_age.get() 
    data_list.insert (END, data)
    
    entry_name_age.delete (0,END)
    entry_name_age.focus()
    
    file = open ("Name_Age.csv", "a")
    temp_list = data_list.get(0,END)
    item = 0
    for row in temp_list: 
        newrecord = temp_list[item] + "\n"
        file.write (str (newrecord))
        item = item +1
        
    file.close()
    


#set up the window 
window = Tk ()
window.geometry("510x300")
window ["bg"] = "lightblue"
window.title ("no. 131, name & age")



#label for entry name 
name_label = Label (text  = "Enter name & age")
name_label.place (x = 20, y = 20, width = 150, height = 30)
name_label ["bg"] = "yellow"
name_label ["fg"] = "blue"


#entry name 
entry_name_age = Entry (text = 0)
entry_name_age.place (x = 190, y = 20, width = 150, height = 30)
entry_name_age["bg"] = "orange"
entry_name_age ["fg"] = "blue"
entry_name_age.focus()



#button create csv 
create_button = Button (text = "Create csv", command = create)
create_button.place (x = 360, y = 20, width = 150, height = 30)
entry_name_age["bg"] = "blue"
entry_name_age ["fg"] = "orange"

#button add csv 
add_button = Button (text = "Add csv", command = add)
add_button.place (x = 360, y = 70, width = 150, height = 30)
add_button["bg"] = "blue"
add_button ["fg"] = "orange"



#list to display 
data_list = Listbox()
data_list.place(x = 190, y = 70, width = 150, height = 70)
data_list ["bg"] = "red"
data_list ["fg"] = "green"

window. mainloop()
