# %%
def code(): 
    #subprogram 1 (encoding)
    baseline = "abcdefghijklmnopqrstuvwxyz "

    text = input("Give me a text you want me to encode: ")
    secret = int(input("What is your secret key? "))
    if secret >= 10 or secret <= -10: 
        secret= int(input("your secret key is out of the range, try it again: "))
        
    lenght = len(text)

    x = 0
    new_text = ""

    for x in range(0, lenght): 
        letter = text [x]
    
        base = baseline.index(letter)
   
        position = base + secret
        
        if position in range(0, len(baseline)):
            new_text = new_text + baseline[position]
        
        
        else: 
            reset = base - len(baseline)
            position = reset + secret 
            new_text = new_text + baseline[position]
        
        x = x +1
    
    print ("\nYour message encodes is: \n")
    print(new_text + "\n")

    
def decode(): 
    #subprogram 2 (Decoding)

    baseline = "abcdefghijklmnopqrstuvwxyz "

    text = input("Give me a text you want me to encode: ")
    secret = int(input("What is your secret key? "))
    if secret >= 10 or secret <= -10: 
        secret= int(input("your secret key is out of the range, try it again: "))
    
    lenght = len(text)

    new_text = ""
    x = 0
    for x in range(0, lenght): 
        letter = text [x]
    
        base = baseline.index(letter)
   
        position = base - secret
        if position in range(0, len(baseline)):
            new_text = new_text +baseline [position]
        
        else: 
            reset = base + len(baseline)
            position = reset - secret 
            new_text = new_text +baseline [position]
        x = x +1
    print ("\nthe secret message behind your text is: \n")
    print (new_text +"\n")
    
    
#main 
   
def main (): 
    print("""
    1. Make a code
    2. Decode a message
    3. Ouit

    """)
    
    go_on = True 
    while go_on == True: 
        select = int(input("Select an option: "))
        if select == 1: 
            code()
        elif select == 2:
            decode()
        elif select == 3: 
            print("\nYou ended the program!")
            go_on = False 
        else: 
            select = int(input("Try again, the selection was wrong: "))
    

main()
