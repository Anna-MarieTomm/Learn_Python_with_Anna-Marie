# %%
import pandas as pd
import numpy as np

#upload file

housing_df = pd.read_csv("HousingData.csv")

housing_df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
#view file
#selects the first 5 rows by default, if number in brackets than this number will be shown 
housing_df.head(10)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575   65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421   78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185   61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998   45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147   54.2  6.0622    3  222     18.7
# 5  0.02985   0.0   2.18   0.0  0.458  6.430   58.7  6.0622    3  222     18.7
# 6  0.08829  12.5   7.87   NaN  0.524  6.012   66.6  5.5605    5  311     15.2
# 7  0.14455  12.5   7.87   0.0  0.524  6.172   96.1  5.9505    5  311     15.2
# 8  0.21124  12.5   7.87   0.0  0.524  5.631  100.0  6.0821    5  311     15.2
# 9  0.17004  12.5   7.87   NaN  0.524  6.004   85.9  6.5921    5  311     15.2
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# ...

# %% [markdown]
# import other data set  (HR Date)

# %%
import pandas as pd
hr_df = pd.read_csv ("03_HR_Employee_Attrition_Data (1).csv")
hr_df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %% [markdown]
# import excel data set

# %%
import pandas as pd
crypto_df = pd.read_excel("Crypto.xlsx")
crypto_df
# Out:
#            Currency    Date(text) Date (date)  year   month   day        Open  \
# 0           bitcoin  Apr 28, 2013  2013-04-28   2013       4   28  135.300000
# 1          litecoin  Apr 28, 2013  2013-04-28   2013       4   28    4.300000
# 2           bitcoin  Apr 29, 2013  2013-04-29   2013       4   29  134.440000
# 3          litecoin  Apr 29, 2013  2013-04-29   2013       4   29    4.370000
# 4           bitcoin  Apr 30, 2013  2013-04-30   2013       4   30  144.000000
# ...             ...           ...         ...    ...     ...  ...         ...
# 13571  bitcoin-cash  Apr 24, 2019  2019-04-24   2019       4   24  290.960000
# 13572       stellar  Apr 24, 2019  2019-04-24   2019       4   24    0.111793
# 13573      litecoin  Apr 24, 2019  2019-04-24   2019       4   24   74.750000
# 13574      ethereum  Apr 24, 2019  2019-04-24   2019       4   24  171.350000
# 13575       cardano  Apr 24, 2019  2019-04-24   2019       4   24    0.074524
#
# ...

# %%
crypto_df.describe()
# Out:
#               year         month            day          Open   Open (num)   \
# count  13576.000000  13576.000000  13576.000000  13576.000000  13576.000000
# mean    2016.528138      6.536903     15.705657    448.618790    448.618790
# std        1.641166      3.525205      8.781564   1610.656909   1610.656909
# min     2013.000000      1.000000      1.000000      0.001352      0.001352
# 25%     2015.000000      3.000000      8.000000      0.219226      0.219225
# 50%     2017.000000      7.000000     16.000000      2.890000      2.890000
# 75%     2018.000000     10.000000     23.000000    132.057500    132.057500
# max     2019.000000     12.000000     31.000000  19475.800000  19475.800000
#
#                High   High (num)            Low    Low (num)          Close  \
# count  13576.000000  13576.000000  13576.000000  13576.000000  13576.000000
# mean     463.023342    463.023342    432.889301    432.889301    448.960363
# ...

# %%
crypto_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13576 entries, 0 to 13575
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Currency           13576 non-null  object
#  1   Date(text)         13576 non-null  object
#  2   Date (date)        13576 non-null  datetime64[ns]
#  3   year               13576 non-null  int64
#  4   month              13576 non-null  int64
#  5   day                13576 non-null  int64
#  6   Open               13576 non-null  float64
#  7   Open (num)         13576 non-null  float64
#  8   High               13576 non-null  float64
#  9   High (num)         13576 non-null  float64
#  10  Low                13576 non-null  float64
#  11  Low (num)          13576 non-null  float64
#  12  Close              13576 non-null  float64
#  13  Close (num)        13576 non-null  float64
#  14  Volume             13576 non-null  object
# ...

# %%
#no parantheses needed (is precomputed)
crypto_df.shape
# Out:
# (13576, 18)
