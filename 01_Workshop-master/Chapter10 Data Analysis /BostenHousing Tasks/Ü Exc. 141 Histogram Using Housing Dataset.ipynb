# %%
import pandas as pd 

housing = pd.read_csv("HousingData.csv")

housing.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %%
#find null values and replace them with median value


housing.loc [:,housing.isnull().any()]
# Out:
#         CRIM    ZN  INDUS  CHAS   AGE  LSTAT
# 0    0.00632  18.0   2.31   0.0  65.2   4.98
# 1    0.02731   0.0   7.07   0.0  78.9   9.14
# 2    0.02729   0.0   7.07   0.0  61.1   4.03
# 3    0.03237   0.0   2.18   0.0  45.8   2.94
# 4    0.06905   0.0   2.18   0.0  54.2    NaN
# ..       ...   ...    ...   ...   ...    ...
# 501  0.06263   0.0  11.93   0.0  69.1    NaN
# 502  0.04527   0.0  11.93   0.0  76.7   9.08
# 503  0.06076   0.0  11.93   0.0  91.0   5.64
# 504  0.10959   0.0  11.93   0.0  89.3   6.48
# 505  0.04741   0.0  11.93   0.0   NaN   7.88
#
# [506 rows x 6 columns]

# %%
housing.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  486.000000  486.000000  486.000000  486.000000  506.000000  506.000000
# mean     3.611874   11.211934   11.083992    0.069959    0.554695    6.284634
# std      8.720192   23.388876    6.835896    0.255340    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.081900    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.253715    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.560262   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  486.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.518519    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
housing.median()
# Out:
# CRIM         0.253715
# ZN           0.000000
# INDUS        9.690000
# CHAS         0.000000
# NOX          0.538000
# RM           6.208500
# AGE         76.800000
# DIS          3.207450
# RAD          5.000000
# TAX        330.000000
# PTRATIO     19.050000
# B          391.440000
# LSTAT       11.430000
# MEDV        21.200000
# dtype: float64

# %%
housing = housing.fillna(housing.median())
housing
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  76.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
#to check if therea are still values with 0 
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
#import visualizatin platform
import matplotlib as plt

#make sure that you see it in juypter
# %matplotlib inline


import seaborn as sns

#dark grid 
sns.set()

#plot histogram for the data 

#MEDV = median value of data set 

plt.pyplot.hist(housing ["MEDV"])
# Out:
# (array([ 21.,  55.,  82., 154.,  84.,  41.,  30.,   8.,  10.,  21.]),
#  array([ 5. ,  9.5, 14. , 18.5, 23. , 27.5, 32. , 36.5, 41. , 45.5, 50. ]),
#  <a list of 10 Patch objects>)

# %%
plt.pyplot.title ("Median house prices in Bosten", fontsize=20)
plt.pyplot.hist(housing ["MEDV"])
plt.pyplot.xlabel("1980 Median Value in T")
plt.pyplot.ylabel("Count")
plt.pyplot.show()
plt.pyplot.figure(figsize=(10,6))

#saving the figure 
plt.pyplot.savefig("Median house prices in Bosten", dpi = 300)
plt.pyplot. show()

# %%
#easier libary useage 

from matplotlib import pyplot as pl 

pl.hist(housing ["MEDV"])
# Out:
# (array([ 21.,  55.,  82., 154.,  84.,  41.,  30.,   8.,  10.,  21.]),
#  array([ 5. ,  9.5, 14. , 18.5, 23. , 27.5, 32. , 36.5, 41. , 45.5, 50. ]),
#  <a list of 10 Patch objects>)
